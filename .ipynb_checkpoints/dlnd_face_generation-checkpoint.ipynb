# %% [markdown]
# # Face Generation
# In this project, you'll use generative adversarial networks to generate new images of faces.
# ### Get the Data
# You'll be using two datasets in this project:
# - MNIST
# - CelebA
#
# Since the celebA dataset is complex and you're doing GANs in a project for the first time, we want you to test your neural network on MNIST before CelebA.  Running the GANs on MNIST will allow you to see how well your model trains sooner.
#
# If you're using [FloydHub](https://www.floydhub.com/), set `data_dir` to "/input" and use the [FloydHub data ID](http://docs.floydhub.com/home/using_datasets/) "R5KrjnANiKVhLWAkpXhNBe".

# %%
data_dir = './data'

# FloydHub - Use with data ID "R5KrjnANiKVhLWAkpXhNBe"
#data_dir = '/input'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper

helper.download_extract('mnist', data_dir)
helper.download_extract('celeba', data_dir)
# Out:
# Found mnist Data
# Found celeba Data

# %% [markdown]
# ## Explore the Data
# ### MNIST
# As you're aware, the [MNIST](http://yann.lecun.com/exdb/mnist/) dataset contains images of handwritten digits. You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
import os
from glob import glob
from matplotlib import pyplot

mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'mnist/*.jpg'))[:show_n_images], 28, 28, 'L')
pyplot.imshow(helper.images_square_grid(mnist_images, 'L'), cmap='gray')

# %% [markdown]
# ### CelebA
# The [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations.  Since you're going to be generating faces, you won't need the annotations.  You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'img_align_celeba/*.jpg'))[:show_n_images], 28, 28, 'RGB')
pyplot.imshow(helper.images_square_grid(mnist_images, 'RGB'))

# %% [markdown]
# ## Preprocess the Data
# Since the project's main focus is on building the GANs, we'll preprocess the data for you.  The values of the MNIST and CelebA dataset will be in the range of -0.5 to 0.5 of 28x28 dimensional images.  The CelebA images will be cropped to remove parts of the image that don't include a face, then resized down to 28x28.
#
# The MNIST images are black and white images with a single [color channel](https://en.wikipedia.org/wiki/Channel_(digital_image%29) while the CelebA images have [3 color channels (RGB color channel)](https://en.wikipedia.org/wiki/Channel_(digital_image%29#RGB_Images).
# ## Build the Neural Network
# You'll build the components necessary to build a GANs by implementing the following functions below:
# - `model_inputs`
# - `discriminator`
# - `generator`
# - `model_loss`
# - `model_opt`
# - `train`
#
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.0'), 'Please use TensorFlow version 1.0 or newer.  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.0.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ### Input
# Implement the `model_inputs` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
# - Real input images placeholder with rank 4 using `image_width`, `image_height`, and `image_channels`.
# - Z input placeholder with rank 2 using `z_dim`.
# - Learning rate placeholder with rank 0.
#
# Return the placeholders in the following the tuple (tensor of real input images, tensor of z data)

# %%
import problem_unittests as tests

def model_inputs(image_width, image_height, image_channels, z_dim):
    """
    Create the model inputs
    :param image_width: The input image width
    :param image_height: The input image height
    :param image_channels: The number of image channels
    :param z_dim: The dimension of Z
    :return: Tuple of (tensor of real input images, tensor of z data, learning rate)
    """
    input_real = tf.placeholder(tf.float32, (None, image_width, image_height, image_channels), name='input_real')
    input_z = tf.placeholder(tf.float32, (None, z_dim), name='input_z')
    learning_rate_in = tf.placeholder(tf.float32, None, name='learning_rate')
    return input_real, input_z, learning_rate_in


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Discriminator
# Implement `discriminator` to create a discriminator neural network that discriminates on `images`.  This function should be able to reuse the variables in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "discriminator" to allow the variables to be reused.  The function should return a tuple of (tensor output of the discriminator, tensor logits of the discriminator).

# %%
def discriminator(images, reuse=False):
    """
    Create the discriminator network
    :param images: Tensor of input image(s)
    :param reuse: Boolean if the weights should be reused
    :return: Tuple of (tensor output of the discriminator, tensor logits of the discriminator)
    """
    alpha = 0.2
    dropout = 0.8
    
    # kernel initializer
    kernel_init = tf.random_normal_initializer(stddev=0.02)
    
    with tf.variable_scope('discriminator', reuse=reuse):
        # Input layer is 28x28x3
        layer1 = tf.layers.conv2d(images, 64, 5, strides=2, kernel_initializer=kernel_init, padding='same')
        layer1 = tf.nn.dropout(layer1, dropout)
        layer1 = tf.maximum(alpha * layer1, layer1)  
        
        # 14x14x64
        
        layer2 = tf.layers.conv2d(layer1, 128, 5, strides=2, kernel_initializer=kernel_init, padding='same')
        layer2 = tf.layers.batch_normalization(layer2, training=True)
        layer2 = tf.nn.dropout(layer2, dropout)
        layer2 = tf.maximum(alpha * layer2, layer2)
        
        # 7x7x128   
        
        layer3 = tf.layers.conv2d(layer2, 256, 5, strides=2, kernel_initializer=kernel_init, padding='same')
        layer3 = tf.layers.batch_normalization(layer3, training=True)
        layer3 = tf.nn.dropout(layer3, dropout)
        layer3 = tf.maximum(alpha * layer3, layer3)
        
        # 4x4x256 

        # Flatten
        flat = tf.reshape(layer3, (-1, 4*4*256))
        logits = tf.layers.dense(flat, 1)        
        out = tf.sigmoid(logits)
        
        return out, logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(discriminator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Generator
# Implement `generator` to generate an image using `z`. This function should be able to reuse the variables in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "generator" to allow the variables to be reused. The function should return the generated 28 x 28 x `out_channel_dim` images.

# %%
def generator(z, out_channel_dim, is_train=True):
    """
    Create the generator network
    :param z: Input z
    :param out_channel_dim: The number of channels in the output image
    :param is_train: Boolean if generator is being used for training
    :return: The tensor output of the generator
    """
    alpha = 0.2 
    dropout = 0.8
    
    # kernel initializer
    kernel_init = tf.random_normal_initializer(stddev=0.02)
    
    with tf.variable_scope("generator", reuse = not is_train):
        # First fully connected layer
        layer1 = tf.layers.dense(z, 7*7*256)        
        layer1 = tf.reshape(layer1, (-1, 7, 7, 256))
        layer1 = tf.layers.batch_normalization(layer1, training=is_train)                
        layer1 = tf.nn.dropout(layer1, dropout)
        layer1 = tf.maximum(alpha * layer1, layer1)           
        
        # 7x7x256
        
        layer2 = tf.layers.conv2d_transpose(layer1, 128, 5, strides=2,  kernel_initializer=kernel_init, padding='same')
        # 7x7x128
        layer2 = tf.layers.batch_normalization(layer2, training=is_train)
        layer2 = tf.nn.dropout(layer2, dropout)
        layer2 = tf.maximum(alpha * layer2, layer2)
        

        
        layer3 = tf.layers.conv2d_transpose(layer2, 64, 5, strides=2,  kernel_initializer=kernel_init, padding='same')
        # 14x14x64
        layer3 = tf.layers.batch_normalization(layer3, training=is_train)
        layer3 = tf.nn.dropout(layer3, dropout)
        layer3 = tf.maximum(alpha * layer3, layer3)
        
          
        # Output layer
        logits = tf.layers.conv2d_transpose(layer3, out_channel_dim , 5, strides=1,  kernel_initializer=kernel_init, padding='same')
        
        # 28x28xout_channel_dim    
        
        out = tf.tanh(logits)
        
        return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(generator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Loss
# Implement `model_loss` to build the GANs for training and calculate the loss.  The function should return a tuple of (discriminator loss, generator loss).  Use the following functions you implemented:
# - `discriminator(images, reuse=False)`
# - `generator(z, out_channel_dim, is_train=True)`

# %%
def model_loss(input_real, input_z, out_channel_dim):
    """
    Get the loss for the discriminator and generator
    :param input_real: Images from the real dataset
    :param input_z: Z input
    :param out_channel_dim: The number of channels in the output image
    :return: A tuple of (discriminator loss, generator loss)
    """
    gen_model = generator(input_z, out_channel_dim)
    dis_model_real, dis_logits_real = discriminator(input_real)
    dis_model_fake, dis_logits_fake = discriminator(gen_model, reuse=True)
    
    dis_loss_real = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=dis_logits_real, labels=tf.ones_like(dis_logits_real) * 0.9))
    dis_loss_fake = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=dis_logits_fake, labels=tf.zeros_like(dis_logits_fake)))
    dis_loss = dis_loss_real + dis_loss_fake
    gen_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=dis_logits_fake, labels=tf.ones_like(dis_logits_fake)))
    
    return dis_loss, gen_loss


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_loss(model_loss)
# Out:
# Tests Passed

# %% [markdown]
# ### Optimization
# Implement `model_opt` to create the optimization operations for the GANs. Use [`tf.trainable_variables`](https://www.tensorflow.org/api_docs/python/tf/trainable_variables) to get all the trainable variables.  Filter the variables with names that are in the discriminator and generator scope names.  The function should return a tuple of (discriminator training operation, generator training operation).

# %%
def model_opt(d_loss, g_loss, learning_rate, beta1):
    """
    Get optimization operations
    :param d_loss: Discriminator loss Tensor
    :param g_loss: Generator loss Tensor
    :param learning_rate: Learning Rate Placeholder
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :return: A tuple of (discriminator training operation, generator training operation)
    """
    train_variables = tf.trainable_variables()
    dis_variables = [var for var in train_variables if var.name.startswith('discriminator')]
    gen_variables = [var for var in train_variables if var.name.startswith('generator')]
    
    update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
    gen_updates = [op for op in update_ops if op.name.startswith('generator')]
    
    with tf.control_dependencies(gen_updates):
        dis_train_ops = tf.train.AdamOptimizer(learning_rate, beta1=beta1).minimize(d_loss, var_list=dis_variables)
        gen_train_ops = tf.train.AdamOptimizer(learning_rate, beta1=beta1).minimize(g_loss, var_list=gen_variables)
    
        return dis_train_ops, gen_train_ops


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_opt(model_opt, tf)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Show Output
# Use this function to show the current output of the generator during training. It will help you determine how well the GANs is training.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

def show_generator_output(sess, n_images, input_z, out_channel_dim, image_mode):
    """
    Show example output for the generator
    :param sess: TensorFlow session
    :param n_images: Number of Images to display
    :param input_z: Input Z Tensor
    :param out_channel_dim: The number of channels in the output image
    :param image_mode: The mode to use for images ("RGB" or "L")
    """
    cmap = None if image_mode == 'RGB' else 'gray'
    z_dim = input_z.get_shape().as_list()[-1]
    example_z = np.random.uniform(-1, 1, size=[n_images, z_dim])

    samples = sess.run(
        generator(input_z, out_channel_dim, False),
        feed_dict={input_z: example_z})

    images_grid = helper.images_square_grid(samples, image_mode)
    pyplot.imshow(images_grid, cmap=cmap)
    pyplot.show()

# %% [markdown]
# ### Train
# Implement `train` to build and train the GANs.  Use the following functions you implemented:
# - `model_inputs(image_width, image_height, image_channels, z_dim)`
# - `model_loss(input_real, input_z, out_channel_dim)`
# - `model_opt(d_loss, g_loss, learning_rate, beta1)`
#
# Use the `show_generator_output` to show `generator` output while you train. Running `show_generator_output` for every batch will drastically increase training time and increase the size of the notebook.  It's recommended to print the `generator` output every 100 batches.

# %%
def train(epoch_count, batch_size, z_dim, learning_rate, beta1, get_batches, data_shape, data_image_mode):
    """
    Train the GAN
    :param epoch_count: Number of epochs
    :param batch_size: Batch Size
    :param z_dim: Z dimension
    :param learning_rate: Learning Rate
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :param get_batches: Function to get batches
    :param data_shape: Shape of the data
    :param data_image_mode: The image mode to use for images ("RGB" or "L")
    """
    _, image_width, image_height, image_channels = data_shape
    
    input_real, input_z, learning_rate_in = model_inputs(image_width, image_height, image_channels, z_dim)
    dis_loss, gen_loss = model_loss(input_real, input_z, image_channels)
    dis_ops, gen_ops = model_opt(dis_loss, gen_loss, learning_rate, beta1)
    
    print_every = 10
    show_every = 100
    steps = 0
    
    saver = tf.train.Saver()
    
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        for epoch_i in range(epoch_count):
            for batch_images in get_batches(batch_size):
                steps += 1
                
                batch_images *= 2
                
                batch_z = np.random.uniform(-1, 1, size=(batch_size, z_dim))
                
                _ = sess.run(dis_ops, feed_dict={ input_real: batch_images, input_z: batch_z, learning_rate_in: learning_rate })
                _ = sess.run(gen_ops, feed_dict={ input_z: batch_z, learning_rate_in: learning_rate })
                
                if steps % print_every == 0:
                    dis_loss_train = dis_loss.eval({
                        input_z: batch_z,
                        input_real: batch_images
                    })
                    gen_loss_train = gen_loss.eval({
                        input_z: batch_z
                    })
                    
                    print("Epoch {}/{}...".format(epoch_i+1, epoch_count),
                          "Generator Loss: {:.4f}".format(gen_loss_train),
                         "Discriminator Loss: {:.4f}...".format(dis_loss_train))
                    
                if steps % show_every == 0:
                    show_generator_output(sess, 25, input_z, image_channels, data_image_mode)

# %% [markdown]
# ### MNIST
# Test your GANs architecture on MNIST.  After 2 epochs, the GANs should be able to generate images that look like handwritten digits.  Make sure the loss of the generator is lower than the loss of the discriminator or close to 0.

# %%
batch_size = 64
z_dim = 128
learning_rate = 0.001
beta1 = 0.5


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 2

mnist_dataset = helper.Dataset('mnist', glob(os.path.join(data_dir, 'mnist/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, mnist_dataset.get_batches,
          mnist_dataset.shape, mnist_dataset.image_mode)
# Out:
# Epoch 1/2... Generator Loss: 0.5114 Discriminator Loss: 2.3731...
# Epoch 1/2... Generator Loss: 13.5943 Discriminator Loss: 4.5319...
# Epoch 1/2... Generator Loss: 5.1419 Discriminator Loss: 0.4297...
# Epoch 1/2... Generator Loss: 5.9615 Discriminator Loss: 0.3851...
# Epoch 1/2... Generator Loss: 1.4709 Discriminator Loss: 1.7719...
# Epoch 1/2... Generator Loss: 0.6177 Discriminator Loss: 2.7631...
# Epoch 1/2... Generator Loss: 2.4494 Discriminator Loss: 0.5662...
# Epoch 1/2... Generator Loss: 1.6520 Discriminator Loss: 0.6970...
# Epoch 1/2... Generator Loss: 2.2735 Discriminator Loss: 0.6595...
# Epoch 1/2... Generator Loss: 0.9161 Discriminator Loss: 1.2923...
# Epoch 1/2... Generator Loss: 0.8609 Discriminator Loss: 1.5412...
# Epoch 1/2... Generator Loss: 1.5835 Discriminator Loss: 0.9991...
# Epoch 1/2... Generator Loss: 0.7453 Discriminator Loss: 1.2504...
# Epoch 1/2... Generator Loss: 0.5934 Discriminator Loss: 2.6449...
# Epoch 1/2... Generator Loss: 1.1574 Discriminator Loss: 0.9216...
# Epoch 1/2... Generator Loss: 0.4680 Discriminator Loss: 1.7352...
# Epoch 1/2... Generator Loss: 1.4804 Discriminator Loss: 0.8989...
# Epoch 1/2... Generator Loss: 1.0297 Discriminator Loss: 1.1798...
# Epoch 1/2... Generator Loss: 1.0166 Discriminator Loss: 1.0034...
# Epoch 1/2... Generator Loss: 1.3641 Discriminator Loss: 1.1316...
# Epoch 1/2... Generator Loss: 0.5772 Discriminator Loss: 1.5102...
# Epoch 1/2... Generator Loss: 1.0289 Discriminator Loss: 1.2273...
# Epoch 1/2... Generator Loss: 0.8416 Discriminator Loss: 1.2804...
# Epoch 1/2... Generator Loss: 0.9773 Discriminator Loss: 1.2443...
# Epoch 1/2... Generator Loss: 1.1534 Discriminator Loss: 1.1807...
# Epoch 1/2... Generator Loss: 1.0948 Discriminator Loss: 1.3144...
# Epoch 1/2... Generator Loss: 1.4222 Discriminator Loss: 1.2621...
# Epoch 1/2... Generator Loss: 0.8072 Discriminator Loss: 1.2746...
# Epoch 1/2... Generator Loss: 0.6046 Discriminator Loss: 1.4796...
# Epoch 1/2... Generator Loss: 1.0492 Discriminator Loss: 1.0792...
# Epoch 1/2... Generator Loss: 1.0658 Discriminator Loss: 1.3103...
# Epoch 1/2... Generator Loss: 1.1134 Discriminator Loss: 1.2615...
# Epoch 1/2... Generator Loss: 0.6798 Discriminator Loss: 1.2794...
# Epoch 1/2... Generator Loss: 0.7630 Discriminator Loss: 1.3040...
# Epoch 1/2... Generator Loss: 1.4022 Discriminator Loss: 1.2718...
# Epoch 1/2... Generator Loss: 1.5755 Discriminator Loss: 1.1537...
# Epoch 1/2... Generator Loss: 0.9387 Discriminator Loss: 1.4661...
# Epoch 1/2... Generator Loss: 1.3870 Discriminator Loss: 1.2359...
# Epoch 1/2... Generator Loss: 1.3402 Discriminator Loss: 1.1742...
# Epoch 1/2... Generator Loss: 0.7347 Discriminator Loss: 1.4052...
# Epoch 1/2... Generator Loss: 0.8049 Discriminator Loss: 1.3264...
# Epoch 1/2... Generator Loss: 1.6292 Discriminator Loss: 1.1761...
# Epoch 1/2... Generator Loss: 0.4986 Discriminator Loss: 1.4813...
# Epoch 1/2... Generator Loss: 1.3621 Discriminator Loss: 1.2079...
# Epoch 1/2... Generator Loss: 1.4188 Discriminator Loss: 1.2058...
# Epoch 1/2... Generator Loss: 1.5176 Discriminator Loss: 1.2119...
# Epoch 1/2... Generator Loss: 0.8904 Discriminator Loss: 1.1951...
# Epoch 1/2... Generator Loss: 0.8939 Discriminator Loss: 1.1349...
# Epoch 1/2... Generator Loss: 0.8836 Discriminator Loss: 1.2913...
# Epoch 1/2... Generator Loss: 1.0842 Discriminator Loss: 1.1938...
# Epoch 1/2... Generator Loss: 1.1087 Discriminator Loss: 1.1103...
# Epoch 1/2... Generator Loss: 1.1455 Discriminator Loss: 1.0377...
# Epoch 1/2... Generator Loss: 0.7324 Discriminator Loss: 1.4453...
# Epoch 1/2... Generator Loss: 0.5523 Discriminator Loss: 1.3208...
# Epoch 1/2... Generator Loss: 1.1140 Discriminator Loss: 1.0629...
# Epoch 1/2... Generator Loss: 1.4003 Discriminator Loss: 1.1783...
# Epoch 1/2... Generator Loss: 1.8232 Discriminator Loss: 1.2514...
# Epoch 1/2... Generator Loss: 1.4120 Discriminator Loss: 1.2787...
# Epoch 1/2... Generator Loss: 1.2151 Discriminator Loss: 1.1652...
# Epoch 1/2... Generator Loss: 0.8210 Discriminator Loss: 1.3299...
# Epoch 1/2... Generator Loss: 1.9075 Discriminator Loss: 1.2399...
# Epoch 1/2... Generator Loss: 1.0627 Discriminator Loss: 1.1173...
# Epoch 1/2... Generator Loss: 1.7247 Discriminator Loss: 0.9437...
# Epoch 1/2... Generator Loss: 1.2876 Discriminator Loss: 1.1055...
# Epoch 1/2... Generator Loss: 0.6074 Discriminator Loss: 1.2754...
# Epoch 1/2... Generator Loss: 1.3223 Discriminator Loss: 0.9762...
# Epoch 1/2... Generator Loss: 1.5685 Discriminator Loss: 1.2253...
# Epoch 1/2... Generator Loss: 1.5845 Discriminator Loss: 1.2594...
# Epoch 1/2... Generator Loss: 0.6065 Discriminator Loss: 1.3833...
# Epoch 1/2... Generator Loss: 0.8415 Discriminator Loss: 1.2114...
# Epoch 1/2... Generator Loss: 0.8585 Discriminator Loss: 1.1060...
# Epoch 1/2... Generator Loss: 0.9788 Discriminator Loss: 1.0663...
# Epoch 1/2... Generator Loss: 1.9035 Discriminator Loss: 1.2929...
# Epoch 1/2... Generator Loss: 1.6837 Discriminator Loss: 1.1648...
# Epoch 1/2... Generator Loss: 0.7957 Discriminator Loss: 1.2979...
# Epoch 1/2... Generator Loss: 1.1149 Discriminator Loss: 1.0226...
# Epoch 1/2... Generator Loss: 1.8369 Discriminator Loss: 1.1273...
# Epoch 1/2... Generator Loss: 0.8204 Discriminator Loss: 1.2611...
# Epoch 1/2... Generator Loss: 1.2211 Discriminator Loss: 0.9721...
# Epoch 1/2... Generator Loss: 0.6512 Discriminator Loss: 1.2310...
# Epoch 1/2... Generator Loss: 0.7260 Discriminator Loss: 1.2278...
# Epoch 1/2... Generator Loss: 2.0934 Discriminator Loss: 1.2594...
# Epoch 1/2... Generator Loss: 0.8076 Discriminator Loss: 1.3270...
# Epoch 1/2... Generator Loss: 0.8725 Discriminator Loss: 1.1620...
# Epoch 1/2... Generator Loss: 0.8530 Discriminator Loss: 1.2851...
# Epoch 1/2... Generator Loss: 0.7783 Discriminator Loss: 1.1693...
# Epoch 1/2... Generator Loss: 1.2942 Discriminator Loss: 1.0532...
# Epoch 1/2... Generator Loss: 1.0727 Discriminator Loss: 1.0707...
# Epoch 1/2... Generator Loss: 0.8470 Discriminator Loss: 1.2039...
# Epoch 1/2... Generator Loss: 0.6322 Discriminator Loss: 1.3458...
# Epoch 1/2... Generator Loss: 1.0211 Discriminator Loss: 1.2350...
# Epoch 1/2... Generator Loss: 2.0265 Discriminator Loss: 1.1469...
# Epoch 1/2... Generator Loss: 1.4366 Discriminator Loss: 1.0173...
# Epoch 2/2... Generator Loss: 0.7712 Discriminator Loss: 1.3382...
# Epoch 2/2... Generator Loss: 1.5984 Discriminator Loss: 1.0481...
# Epoch 2/2... Generator Loss: 1.6020 Discriminator Loss: 1.0642...
# Epoch 2/2... Generator Loss: 0.9729 Discriminator Loss: 0.9705...
# Epoch 2/2... Generator Loss: 0.8623 Discriminator Loss: 1.0609...
# Epoch 2/2... Generator Loss: 0.9494 Discriminator Loss: 1.0828...
# Epoch 2/2... Generator Loss: 1.9064 Discriminator Loss: 1.3659...
# Epoch 2/2... Generator Loss: 1.1979 Discriminator Loss: 1.1015...
# Epoch 2/2... Generator Loss: 1.3067 Discriminator Loss: 1.0237...
# Epoch 2/2... Generator Loss: 1.4672 Discriminator Loss: 0.9912...
# Epoch 2/2... Generator Loss: 1.3828 Discriminator Loss: 1.1020...
# Epoch 2/2... Generator Loss: 0.5948 Discriminator Loss: 1.4049...
# Epoch 2/2... Generator Loss: 2.3708 Discriminator Loss: 1.3139...
# Epoch 2/2... Generator Loss: 1.1634 Discriminator Loss: 1.1162...
# Epoch 2/2... Generator Loss: 1.2489 Discriminator Loss: 1.0132...
# Epoch 2/2... Generator Loss: 0.9135 Discriminator Loss: 1.1359...
# Epoch 2/2... Generator Loss: 0.8281 Discriminator Loss: 1.1969...
# Epoch 2/2... Generator Loss: 1.3608 Discriminator Loss: 1.0360...
# Epoch 2/2... Generator Loss: 1.8889 Discriminator Loss: 1.2644...
# Epoch 2/2... Generator Loss: 0.8861 Discriminator Loss: 0.9937...
# Epoch 2/2... Generator Loss: 0.7672 Discriminator Loss: 1.3367...
# Epoch 2/2... Generator Loss: 1.3284 Discriminator Loss: 0.9695...
# Epoch 2/2... Generator Loss: 1.1840 Discriminator Loss: 1.0885...
# Epoch 2/2... Generator Loss: 1.2244 Discriminator Loss: 1.0532...
# Epoch 2/2... Generator Loss: 1.1769 Discriminator Loss: 0.9609...
# Epoch 2/2... Generator Loss: 0.5040 Discriminator Loss: 1.5057...
# Epoch 2/2... Generator Loss: 0.7697 Discriminator Loss: 1.2000...
# Epoch 2/2... Generator Loss: 1.0829 Discriminator Loss: 1.0500...
# Epoch 2/2... Generator Loss: 1.5024 Discriminator Loss: 0.9602...
# Epoch 2/2... Generator Loss: 0.9949 Discriminator Loss: 1.0078...
# Epoch 2/2... Generator Loss: 1.0906 Discriminator Loss: 1.0230...
# Epoch 2/2... Generator Loss: 1.5001 Discriminator Loss: 1.0115...
# Epoch 2/2... Generator Loss: 1.3430 Discriminator Loss: 1.0430...
# Epoch 2/2... Generator Loss: 2.5806 Discriminator Loss: 1.3841...
# Epoch 2/2... Generator Loss: 1.0029 Discriminator Loss: 1.0481...
# Epoch 2/2... Generator Loss: 1.7622 Discriminator Loss: 0.9175...
# Epoch 2/2... Generator Loss: 1.0218 Discriminator Loss: 1.1288...
# Epoch 2/2... Generator Loss: 1.5523 Discriminator Loss: 0.9396...
# Epoch 2/2... Generator Loss: 2.6434 Discriminator Loss: 1.6373...
# Epoch 2/2... Generator Loss: 1.6930 Discriminator Loss: 1.0855...
# Epoch 2/2... Generator Loss: 1.5263 Discriminator Loss: 1.1454...
# Epoch 2/2... Generator Loss: 2.2193 Discriminator Loss: 1.2630...
# Epoch 2/2... Generator Loss: 1.0016 Discriminator Loss: 1.1828...
# Epoch 2/2... Generator Loss: 0.8162 Discriminator Loss: 1.3158...
# Epoch 2/2... Generator Loss: 1.3756 Discriminator Loss: 0.8848...
# Epoch 2/2... Generator Loss: 1.7033 Discriminator Loss: 1.1341...
# Epoch 2/2... Generator Loss: 2.4605 Discriminator Loss: 0.8826...
# Epoch 2/2... Generator Loss: 1.5292 Discriminator Loss: 0.9361...
# Epoch 2/2... Generator Loss: 1.0041 Discriminator Loss: 1.0525...
# Epoch 2/2... Generator Loss: 0.8119 Discriminator Loss: 1.2412...
# Epoch 2/2... Generator Loss: 2.1754 Discriminator Loss: 1.4829...
# Epoch 2/2... Generator Loss: 0.7282 Discriminator Loss: 1.2060...
# Epoch 2/2... Generator Loss: 1.5664 Discriminator Loss: 0.9403...
# Epoch 2/2... Generator Loss: 1.3590 Discriminator Loss: 0.9336...
# Epoch 2/2... Generator Loss: 2.0614 Discriminator Loss: 1.2024...
# Epoch 2/2... Generator Loss: 1.7633 Discriminator Loss: 0.8218...
# Epoch 2/2... Generator Loss: 1.4717 Discriminator Loss: 1.0579...
# Epoch 2/2... Generator Loss: 1.6306 Discriminator Loss: 1.1055...
# Epoch 2/2... Generator Loss: 0.6460 Discriminator Loss: 1.2936...
# Epoch 2/2... Generator Loss: 1.0577 Discriminator Loss: 0.9558...
# Epoch 2/2... Generator Loss: 1.3673 Discriminator Loss: 0.9554...
# Epoch 2/2... Generator Loss: 0.7194 Discriminator Loss: 1.2377...
# Epoch 2/2... Generator Loss: 1.2357 Discriminator Loss: 1.0378...
# Epoch 2/2... Generator Loss: 1.5725 Discriminator Loss: 1.1735...
# Epoch 2/2... Generator Loss: 1.2580 Discriminator Loss: 1.0421...
# Epoch 2/2... Generator Loss: 1.3984 Discriminator Loss: 0.8825...
# Epoch 2/2... Generator Loss: 1.4373 Discriminator Loss: 0.9334...
# Epoch 2/2... Generator Loss: 1.3349 Discriminator Loss: 0.8724...
# Epoch 2/2... Generator Loss: 2.3195 Discriminator Loss: 1.1497...
# Epoch 2/2... Generator Loss: 1.9257 Discriminator Loss: 0.8568...
# Epoch 2/2... Generator Loss: 0.6528 Discriminator Loss: 1.3604...
# Epoch 2/2... Generator Loss: 1.1544 Discriminator Loss: 0.9218...
# Epoch 2/2... Generator Loss: 2.1041 Discriminator Loss: 1.0909...
# Epoch 2/2... Generator Loss: 1.2994 Discriminator Loss: 1.0561...
# Epoch 2/2... Generator Loss: 2.2147 Discriminator Loss: 1.0543...
# Epoch 2/2... Generator Loss: 1.7925 Discriminator Loss: 0.8112...
# Epoch 2/2... Generator Loss: 1.0552 Discriminator Loss: 1.0087...
# Epoch 2/2... Generator Loss: 1.1800 Discriminator Loss: 1.0333...
# Epoch 2/2... Generator Loss: 1.5390 Discriminator Loss: 0.8286...
# Epoch 2/2... Generator Loss: 1.0297 Discriminator Loss: 1.0691...
# Epoch 2/2... Generator Loss: 0.6461 Discriminator Loss: 1.2789...
# Epoch 2/2... Generator Loss: 2.0487 Discriminator Loss: 0.7117...
# Epoch 2/2... Generator Loss: 0.6138 Discriminator Loss: 1.5253...
# Epoch 2/2... Generator Loss: 1.1279 Discriminator Loss: 0.9287...
# Epoch 2/2... Generator Loss: 1.3466 Discriminator Loss: 0.9551...
# Epoch 2/2... Generator Loss: 1.3464 Discriminator Loss: 1.1691...
# Epoch 2/2... Generator Loss: 1.2047 Discriminator Loss: 1.1538...
# Epoch 2/2... Generator Loss: 1.1893 Discriminator Loss: 0.9134...
# Epoch 2/2... Generator Loss: 0.9072 Discriminator Loss: 1.1051...
# Epoch 2/2... Generator Loss: 2.1813 Discriminator Loss: 0.8045...
# Epoch 2/2... Generator Loss: 1.3146 Discriminator Loss: 0.8212...
# Epoch 2/2... Generator Loss: 1.5485 Discriminator Loss: 0.9015...
# Epoch 2/2... Generator Loss: 3.1699 Discriminator Loss: 2.1048...
# Epoch 2/2... Generator Loss: 1.4872 Discriminator Loss: 0.8805...

# %% [markdown]
# ### CelebA
# Run your GANs on CelebA.  It will take around 20 minutes on the average GPU to run one epoch.  You can run the whole epoch or stop when it starts to generate realistic faces.

# %%
batch_size = 128
z_dim = 100
learning_rate = 0.0001
beta1 = 0.5


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 1

celeba_dataset = helper.Dataset('celeba', glob(os.path.join(data_dir, 'img_align_celeba/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, celeba_dataset.get_batches,
          celeba_dataset.shape, celeba_dataset.image_mode)
# Out:
# Epoch 1/1... Generator Loss: 2.2130 Discriminator Loss: 0.7181...
# Epoch 1/1... Generator Loss: 2.5209 Discriminator Loss: 0.5654...
# Epoch 1/1... Generator Loss: 3.0881 Discriminator Loss: 0.5003...
# Epoch 1/1... Generator Loss: 2.8085 Discriminator Loss: 0.5271...
# Epoch 1/1... Generator Loss: 2.9836 Discriminator Loss: 0.5385...
# Epoch 1/1... Generator Loss: 2.1349 Discriminator Loss: 0.6150...
# Epoch 1/1... Generator Loss: 2.8893 Discriminator Loss: 0.5583...
# Epoch 1/1... Generator Loss: 4.0347 Discriminator Loss: 0.6498...
# Epoch 1/1... Generator Loss: 1.9567 Discriminator Loss: 0.6874...
# Epoch 1/1... Generator Loss: 2.9138 Discriminator Loss: 0.5875...
# Epoch 1/1... Generator Loss: 2.3977 Discriminator Loss: 0.6010...
# Epoch 1/1... Generator Loss: 3.0693 Discriminator Loss: 0.5347...
# Epoch 1/1... Generator Loss: 3.2955 Discriminator Loss: 0.5764...
# Epoch 1/1... Generator Loss: 3.7808 Discriminator Loss: 0.5033...
# Epoch 1/1... Generator Loss: 3.4101 Discriminator Loss: 0.5111...
# Epoch 1/1... Generator Loss: 3.2554 Discriminator Loss: 0.4689...
# Epoch 1/1... Generator Loss: 3.9259 Discriminator Loss: 0.4870...
# Epoch 1/1... Generator Loss: 3.0811 Discriminator Loss: 0.4872...
# Epoch 1/1... Generator Loss: 1.7086 Discriminator Loss: 0.7759...
# Epoch 1/1... Generator Loss: 3.6133 Discriminator Loss: 0.4305...
# Epoch 1/1... Generator Loss: 3.4487 Discriminator Loss: 0.4309...
# Epoch 1/1... Generator Loss: 4.0087 Discriminator Loss: 0.4913...
# Epoch 1/1... Generator Loss: 3.8184 Discriminator Loss: 0.4361...
# Epoch 1/1... Generator Loss: 3.4142 Discriminator Loss: 0.4472...
# Epoch 1/1... Generator Loss: 3.7175 Discriminator Loss: 0.4720...
# Epoch 1/1... Generator Loss: 4.2520 Discriminator Loss: 0.4301...
# Epoch 1/1... Generator Loss: 3.3364 Discriminator Loss: 0.5005...
# Epoch 1/1... Generator Loss: 3.6632 Discriminator Loss: 0.4587...
# Epoch 1/1... Generator Loss: 3.6752 Discriminator Loss: 0.5078...
# Epoch 1/1... Generator Loss: 3.4665 Discriminator Loss: 0.5378...
# Epoch 1/1... Generator Loss: 3.7819 Discriminator Loss: 0.4745...
# Epoch 1/1... Generator Loss: 1.9639 Discriminator Loss: 0.6069...
# Epoch 1/1... Generator Loss: 2.4565 Discriminator Loss: 0.5890...
# Epoch 1/1... Generator Loss: 2.5854 Discriminator Loss: 0.5451...
# Epoch 1/1... Generator Loss: 2.8814 Discriminator Loss: 0.5451...
# Epoch 1/1... Generator Loss: 2.6963 Discriminator Loss: 0.5332...
# Epoch 1/1... Generator Loss: 1.8103 Discriminator Loss: 0.6927...
# Epoch 1/1... Generator Loss: 1.8267 Discriminator Loss: 0.6928...
# Epoch 1/1... Generator Loss: 3.6473 Discriminator Loss: 1.0569...
# Epoch 1/1... Generator Loss: 2.2887 Discriminator Loss: 0.6794...
# Epoch 1/1... Generator Loss: 1.8443 Discriminator Loss: 0.7422...
# Epoch 1/1... Generator Loss: 2.5255 Discriminator Loss: 0.7038...
# Epoch 1/1... Generator Loss: 1.6598 Discriminator Loss: 0.7309...
# Epoch 1/1... Generator Loss: 2.7140 Discriminator Loss: 0.7163...
# Epoch 1/1... Generator Loss: 2.6864 Discriminator Loss: 0.7787...
# Epoch 1/1... Generator Loss: 1.8148 Discriminator Loss: 0.8871...
# Epoch 1/1... Generator Loss: 2.8323 Discriminator Loss: 0.8063...
# Epoch 1/1... Generator Loss: 2.0627 Discriminator Loss: 0.7754...
# Epoch 1/1... Generator Loss: 2.2041 Discriminator Loss: 0.6135...
# Epoch 1/1... Generator Loss: 1.9911 Discriminator Loss: 0.7389...
# Epoch 1/1... Generator Loss: 1.4922 Discriminator Loss: 0.9403...
# Epoch 1/1... Generator Loss: 1.6614 Discriminator Loss: 0.8460...
# Epoch 1/1... Generator Loss: 3.2226 Discriminator Loss: 0.9212...
# Epoch 1/1... Generator Loss: 2.6700 Discriminator Loss: 0.7023...
# Epoch 1/1... Generator Loss: 2.3115 Discriminator Loss: 0.6125...
# Epoch 1/1... Generator Loss: 3.3557 Discriminator Loss: 1.2719...
# Epoch 1/1... Generator Loss: 1.5217 Discriminator Loss: 0.8399...
# Epoch 1/1... Generator Loss: 2.3614 Discriminator Loss: 0.8126...
# Epoch 1/1... Generator Loss: 0.9051 Discriminator Loss: 1.2015...
# Epoch 1/1... Generator Loss: 2.6072 Discriminator Loss: 0.8210...
# Epoch 1/1... Generator Loss: 1.9735 Discriminator Loss: 0.7565...
# Epoch 1/1... Generator Loss: 1.8841 Discriminator Loss: 0.8393...
# Epoch 1/1... Generator Loss: 1.8126 Discriminator Loss: 0.8035...
# Epoch 1/1... Generator Loss: 2.1210 Discriminator Loss: 0.7919...
# Epoch 1/1... Generator Loss: 2.0806 Discriminator Loss: 0.6721...
# Epoch 1/1... Generator Loss: 1.5385 Discriminator Loss: 0.9022...
# Epoch 1/1... Generator Loss: 0.9996 Discriminator Loss: 1.3775...
# Epoch 1/1... Generator Loss: 2.8212 Discriminator Loss: 0.8687...
# Epoch 1/1... Generator Loss: 1.6422 Discriminator Loss: 0.8724...
# Epoch 1/1... Generator Loss: 2.1706 Discriminator Loss: 0.8083...
# Epoch 1/1... Generator Loss: 1.4665 Discriminator Loss: 1.0286...
# Epoch 1/1... Generator Loss: 1.2337 Discriminator Loss: 0.9731...
# Epoch 1/1... Generator Loss: 1.4626 Discriminator Loss: 1.0013...
# Epoch 1/1... Generator Loss: 1.6190 Discriminator Loss: 0.9732...
# Epoch 1/1... Generator Loss: 2.3511 Discriminator Loss: 0.8730...
# Epoch 1/1... Generator Loss: 1.3174 Discriminator Loss: 1.0778...
# Epoch 1/1... Generator Loss: 1.4387 Discriminator Loss: 0.9503...
# Epoch 1/1... Generator Loss: 1.5171 Discriminator Loss: 0.9462...
# Epoch 1/1... Generator Loss: 1.6503 Discriminator Loss: 1.1168...
# Epoch 1/1... Generator Loss: 1.6759 Discriminator Loss: 0.8682...
# Epoch 1/1... Generator Loss: 1.7628 Discriminator Loss: 1.0492...
# Epoch 1/1... Generator Loss: 2.0507 Discriminator Loss: 1.0260...
# Epoch 1/1... Generator Loss: 1.6224 Discriminator Loss: 0.8508...
# Epoch 1/1... Generator Loss: 1.7640 Discriminator Loss: 1.1570...
# Epoch 1/1... Generator Loss: 1.8352 Discriminator Loss: 0.8020...
# Epoch 1/1... Generator Loss: 1.9009 Discriminator Loss: 0.9413...
# Epoch 1/1... Generator Loss: 1.0203 Discriminator Loss: 1.1716...
# Epoch 1/1... Generator Loss: 2.2139 Discriminator Loss: 0.9387...
# Epoch 1/1... Generator Loss: 1.6685 Discriminator Loss: 1.1464...
# Epoch 1/1... Generator Loss: 1.4348 Discriminator Loss: 0.9340...
# Epoch 1/1... Generator Loss: 1.2276 Discriminator Loss: 0.9847...
# Epoch 1/1... Generator Loss: 0.8809 Discriminator Loss: 1.3070...
# Epoch 1/1... Generator Loss: 1.5902 Discriminator Loss: 1.0936...
# Epoch 1/1... Generator Loss: 1.8151 Discriminator Loss: 1.0062...
# Epoch 1/1... Generator Loss: 2.0850 Discriminator Loss: 1.1197...
# Epoch 1/1... Generator Loss: 1.2179 Discriminator Loss: 1.3173...
# Epoch 1/1... Generator Loss: 1.6626 Discriminator Loss: 0.8988...
# Epoch 1/1... Generator Loss: 2.0283 Discriminator Loss: 1.2802...
# Epoch 1/1... Generator Loss: 1.4817 Discriminator Loss: 0.9782...
# Epoch 1/1... Generator Loss: 1.3135 Discriminator Loss: 1.0166...
# Epoch 1/1... Generator Loss: 1.3642 Discriminator Loss: 1.0753...
# Epoch 1/1... Generator Loss: 1.4599 Discriminator Loss: 1.1359...
# Epoch 1/1... Generator Loss: 1.1192 Discriminator Loss: 1.1376...
# Epoch 1/1... Generator Loss: 1.5746 Discriminator Loss: 0.9765...
# Epoch 1/1... Generator Loss: 1.2407 Discriminator Loss: 1.1207...
# Epoch 1/1... Generator Loss: 1.2880 Discriminator Loss: 1.0701...
# Epoch 1/1... Generator Loss: 1.9070 Discriminator Loss: 1.2407...
# Epoch 1/1... Generator Loss: 0.9711 Discriminator Loss: 1.1842...
# Epoch 1/1... Generator Loss: 1.5289 Discriminator Loss: 1.2413...
# Epoch 1/1... Generator Loss: 1.0939 Discriminator Loss: 1.1819...
# Epoch 1/1... Generator Loss: 1.4340 Discriminator Loss: 1.0510...
# Epoch 1/1... Generator Loss: 1.4938 Discriminator Loss: 1.0098...
# Epoch 1/1... Generator Loss: 0.8466 Discriminator Loss: 1.2933...
# Epoch 1/1... Generator Loss: 0.8759 Discriminator Loss: 1.2081...
# Epoch 1/1... Generator Loss: 1.2996 Discriminator Loss: 1.0327...
# Epoch 1/1... Generator Loss: 1.3832 Discriminator Loss: 1.1711...
# Epoch 1/1... Generator Loss: 1.1379 Discriminator Loss: 1.1030...
# Epoch 1/1... Generator Loss: 1.5477 Discriminator Loss: 1.0763...
# Epoch 1/1... Generator Loss: 1.0903 Discriminator Loss: 1.1123...
# Epoch 1/1... Generator Loss: 1.2094 Discriminator Loss: 1.0855...
# Epoch 1/1... Generator Loss: 1.5606 Discriminator Loss: 1.0651...
# Epoch 1/1... Generator Loss: 1.0688 Discriminator Loss: 1.2034...
# Epoch 1/1... Generator Loss: 1.4089 Discriminator Loss: 0.9972...
# Epoch 1/1... Generator Loss: 0.9682 Discriminator Loss: 1.1706...
# Epoch 1/1... Generator Loss: 1.3641 Discriminator Loss: 1.0002...
# Epoch 1/1... Generator Loss: 1.3408 Discriminator Loss: 1.0186...
# Epoch 1/1... Generator Loss: 1.0592 Discriminator Loss: 1.0870...
# Epoch 1/1... Generator Loss: 1.2696 Discriminator Loss: 1.1127...
# Epoch 1/1... Generator Loss: 0.9897 Discriminator Loss: 1.1564...
# Epoch 1/1... Generator Loss: 1.1587 Discriminator Loss: 1.0821...
# Epoch 1/1... Generator Loss: 1.4468 Discriminator Loss: 0.9942...
# Epoch 1/1... Generator Loss: 1.6345 Discriminator Loss: 1.0604...
# Epoch 1/1... Generator Loss: 1.2442 Discriminator Loss: 1.0767...
# Epoch 1/1... Generator Loss: 1.1472 Discriminator Loss: 1.0264...
# Epoch 1/1... Generator Loss: 1.9117 Discriminator Loss: 1.1522...
# Epoch 1/1... Generator Loss: 1.2982 Discriminator Loss: 1.0948...
# Epoch 1/1... Generator Loss: 1.5358 Discriminator Loss: 1.1449...
# Epoch 1/1... Generator Loss: 1.6792 Discriminator Loss: 1.0158...
# Epoch 1/1... Generator Loss: 1.8096 Discriminator Loss: 1.2258...
# Epoch 1/1... Generator Loss: 1.3950 Discriminator Loss: 1.1249...
# Epoch 1/1... Generator Loss: 1.2160 Discriminator Loss: 1.0655...
# Epoch 1/1... Generator Loss: 1.1836 Discriminator Loss: 1.0437...
# Epoch 1/1... Generator Loss: 1.2949 Discriminator Loss: 1.0263...
# Epoch 1/1... Generator Loss: 1.5028 Discriminator Loss: 1.0509...
# Epoch 1/1... Generator Loss: 1.4856 Discriminator Loss: 1.0789...
# Epoch 1/1... Generator Loss: 1.7681 Discriminator Loss: 1.0724...
# Epoch 1/1... Generator Loss: 1.6109 Discriminator Loss: 0.9691...
# Epoch 1/1... Generator Loss: 0.9368 Discriminator Loss: 1.1029...
# Epoch 1/1... Generator Loss: 1.1609 Discriminator Loss: 0.9904...
# Epoch 1/1... Generator Loss: 1.6313 Discriminator Loss: 1.0052...
# Epoch 1/1... Generator Loss: 1.5128 Discriminator Loss: 1.0929...
# Epoch 1/1... Generator Loss: 1.3754 Discriminator Loss: 1.0170...
# Epoch 1/1... Generator Loss: 1.5010 Discriminator Loss: 0.9544...
# Epoch 1/1... Generator Loss: 1.4734 Discriminator Loss: 0.9546...
# Epoch 1/1... Generator Loss: 1.1574 Discriminator Loss: 1.1521...
# Epoch 1/1... Generator Loss: 1.7231 Discriminator Loss: 0.9258...
# Epoch 1/1... Generator Loss: 1.5272 Discriminator Loss: 0.9792...
# Epoch 1/1... Generator Loss: 1.4830 Discriminator Loss: 1.0651...

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
